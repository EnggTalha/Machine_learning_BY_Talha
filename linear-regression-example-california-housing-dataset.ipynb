# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import fetch_california_housing
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Load the California housing dataset
california_housing = fetch_california_housing(as_frame=True)
data = california_housing.data
target = california_housing.target

# Display the first few rows of the dataset
print("First five rows of the California housing dataset:")
print(data.head())

# Check for missing values
print("\nMissing values in each column:")
print(data.isnull().sum())
# Out:
# First five rows of the California housing dataset:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude
# 0    -122.23
# 1    -122.22
# 2    -122.24
# 3    -122.25
# 4    -122.25
#
# Missing values in each column:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
# Visualize the target variable (house prices)
plt.figure(figsize=(10, 6))
sns.histplot(target, bins=30, kde=True)
plt.title("Distribution of House Prices")
plt.xlabel("House Price")
plt.ylabel("Frequency")
plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Split the dataset into training and test sets
X_train, X_test, y_train, y_test = train_test_split(data, target, test_size=0.2, random_state=42)

# Create a Linear Regression model
model = LinearRegression()

# Train the model
model.fit(X_train, y_train)

# Make predictions
y_pred = model.predict(X_test)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"\nMean Squared Error: {mse:.2f}")
print(f"R-squared: {r2:.2f}")
# Out:
# Mean Squared Error: 0.56
# R-squared: 0.58

# %%
# Print evaluation metrics
print("\nMean Squared Error:", mse)
print("R-squared Score:", r2)

# Visualize actual vs predicted prices
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred, alpha=0.6)
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'r--')
plt.title("Actual vs Predicted House Prices")
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.show()
# Out:
# Mean Squared Error: 0.5558915986952443
# R-squared Score: 0.5757877060324508

# %%
# Define a function for question detection and answering
def answer_question(question):
    # Simple keyword-based questions and answers
    qa_pairs = {
        "mean squared error": "The Mean Squared Error (MSE) indicates how close the predictions are to the actual values. A lower MSE is preferable.",
        "r-squared": "The R-squared value indicates the proportion of variance in the target variable that is predictable from the features. An R-squared value closer to 1 suggests a good fit.",
        "feature importance": "Feature importance can be assessed using the coefficients of the linear regression model. Larger absolute values indicate more important features.",
        "overfitting": "Overfitting occurs when the model performs well on training data but poorly on test data. Techniques to address this include regularization and using simpler models.",
        "assumptions": "Key assumptions of linear regression include linearity, independence, homoscedasticity, and normality of residuals.",
        "prediction visualization": "A scatter plot of actual vs. predicted values helps assess model performance. Ideally, points should be close to a 45-degree line.",
        "feature scaling": "Feature scaling is important for algorithms like Linear Regression because it ensures that all features contribute equally to the model training.",
        "comparative analysis": "Linear Regression is simple and interpretable but may not capture complex relationships as well as models like Random Forest or Gradient Boosting."
    }
    
    # Check for keywords in the user's question
    question = question.lower()
    for key in qa_pairs:
        if key in question:
            return qa_pairs[key]
    
    return "I'm sorry, I don't have an answer for that question."

# Interactive question input
while True:
    user_question = input("Ask a question about the Linear Regression model (or type 'exit' to quit): ")
    if user_question.lower() == 'exit':
        print("Exiting question session.")
        break
    answer = answer_question(user_question)
    print(f"Answer: {answer}")
# Out:
# Ask a question about the Linear Regression model (or type 'exit' to quit):  What does the Mean Squared Error indicate about the model's predictions?
# Answer: The Mean Squared Error (MSE) indicates how close the predictions are to the actual values. A lower MSE is preferable.
# Ask a question about the Linear Regression model (or type 'exit' to quit):  hi
# Answer: I'm sorry, I don't have an answer for that question.
# Exception ignored in: <bound method IPythonKernel._clean_thread_parent_frames of <ipykernel.ipkernel.IPythonKernel object at 0x7a8e172afe20>>
# Traceback (most recent call last):
#   File "/opt/conda/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 775, in _clean_thread_parent_frames
#     def _clean_thread_parent_frames(
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 25
#      23 # Interactive question input
# ...
